# %%
# !pip install pandas

# %%
import pandas as pd

# %%
#Series is an one dimensional labelled array

# %%
l=['python','java','javascript','c++']

# %%
type(l)
# Out:
# list

# %%
o = pd.Series(l)

# %%
o
# Out:
# 0        python
# 1          java
# 2    javascript
# 3           c++
# dtype: object

# %%
type(o)
# Out:
# pandas.core.series.Series

# %%
o[2]
# Out:
# 'javascript'

# %%
o.index= ['a','b','c','d']

# %%
o
# Out:
# a        python
# b          java
# c    javascript
# d           c++
# dtype: object

# %%
o[3]
# Out:
# 'c++'

# %%
#DAta fram 2dimensional array

# %%
import numpy as np

# %%
j = np.random.randint(10,100,size = (6,4))
j
# Out:
# array([[32, 86, 23, 16],
#        [44, 38, 58, 51],
#        [50, 89, 71, 51],
#        [22, 13, 47, 42],
#        [93, 11, 36, 30],
#        [97, 71, 65, 91]])

# %%
f = pd.DataFrame(j)

# %%
f
# Out:
#     0   1   2   3
# 0  32  86  23  16
# 1  44  38  58  51
# 2  50  89  71  51
# 3  22  13  47  42
# 4  93  11  36  30
# 5  97  71  65  91

# %%
type(f)
# Out:
# pandas.core.frame.DataFrame

# %%
f[2]
# Out:
# 0    23
# 1    58
# 2    71
# 3    47
# 4    36
# 5    65
# Name: 2, dtype: int32

# %%
f[[1,2]]
# Out:
#     1   2
# 0  86  23
# 1  38  58
# 2  89  71
# 3  13  47
# 4  11  36
# 5  71  65

# %%
f.columns = ['a','b','c','d']

# %%
f
# Out:
#     a   b   c   d
# 0  32  86  23  16
# 1  44  38  58  51
# 2  50  89  71  51
# 3  22  13  47  42
# 4  93  11  36  30
# 5  97  71  65  91

# %%
f['c']
# Out:
# 0    23
# 1    58
# 2    71
# 3    47
# 4    36
# 5    65
# Name: c, dtype: int32

# %%
f.shape
# Out:
# (6, 4)

# %%
f.head() #shuru ki 5 row dikhayga
# Out:
#     a   b   c   d
# 0  32  86  23  16
# 1  44  38  58  51
# 2  50  89  71  51
# 3  22  13  47  42
# 4  93  11  36  30

# %%
f.tail(2)  # Last ki row dikhayga
# Out:
#     a   b   c   d
# 4  93  11  36  30
# 5  97  71  65  91

# %%
type(f['a'])
# Out:
# pandas.core.series.Series

# %%
type(f[['a']])
# Out:
# pandas.core.frame.DataFrame

# %%
f['e']=f['a']+f['b']

# %%
f
# Out:
#     a   b   c   d    e
# 0  32  86  23  16  118
# 1  44  38  58  51   82
# 2  50  89  71  51  139
# 3  22  13  47  42   35
# 4  93  11  36  30  104
# 5  97  71  65  91  168

# %%
f['g'] = f['c']-f['a']

# %%
f
# Out:
#     a   b   c   d    e   g
# 0  32  86  23  16  118  -9
# 1  44  38  58  51   82  14
# 2  50  89  71  51  139  21
# 3  22  13  47  42   35  25
# 4  93  11  36  30  104 -57
# 5  97  71  65  91  168 -32

# %%
f = f.drop('e', axis=1) #by deafult axis is 0 which is row

# %%
f
# Out:
#     a   b   c   d   g
# 0  32  86  23  16  -9
# 1  44  38  58  51  14
# 2  50  89  71  51  21
# 3  22  13  47  42  25
# 4  93  11  36  30 -57
# 5  97  71  65  91 -32

# %%
f.drop("d" ,axis = 1, inplace=True)

# %%
f
# Out:
#     a   b   c   g
# 0  32  86  23  -9
# 1  44  38  58  14
# 2  50  89  71  21
# 3  22  13  47  25
# 4  93  11  36 -57
# 5  97  71  65 -32

# %%
f.drop(['b','c','g'], axis = 1, inplace=True)

# %%
f
# Out:
#     a
# 0  32
# 1  44
# 2  50
# 3  22
# 4  93
# 5  97

# %%
# !pip install pandas

# %%
import pandas as pd

# %%
j = np.random.randint(10,100,size = (6,4))
j
# Out:
# array([[92, 64, 63, 90],
#        [22, 69, 34, 24],
#        [22, 96, 89, 59],
#        [81, 39, 75, 10],
#        [48, 40, 75, 66],
#        [29, 46, 68, 82]])

# %%
import numpy as np

# %%
j = np.random.randint(10,100,size = (6,4))
j
# Out:
# array([[97, 94, 83, 76],
#        [98, 34, 68, 41],
#        [44, 59, 32, 45],
#        [54, 36, 46, 66],
#        [87, 63, 18, 92],
#        [40, 90, 59, 59]])

# %%
f = pd.DataFrame(j)

# %%
f
# Out:
#     0   1   2   3
# 0  97  94  83  76
# 1  98  34  68  41
# 2  44  59  32  45
# 3  54  36  46  66
# 4  87  63  18  92
# 5  40  90  59  59

# %%
f.index = 'p q r s t u'.split()

# %%
f
# Out:
#     0   1   2   3
# p  97  94  83  76
# q  98  34  68  41
# r  44  59  32  45
# s  54  36  46  66
# t  87  63  18  92
# u  40  90  59  59

# %%
f.loc['p']  # loc direct variable ki
# Out:
# 0    97
# 1    94
# 2    83
# 3    76
# Name: p, dtype: int32

# %%
f.iloc[0]  # iloc index ki value uthayga
# Out:
# 0    97
# 1    94
# 2    83
# 3    76
# Name: p, dtype: int32

# %%
f.loc['s']
# Out:
# 0    54
# 1    36
# 2    46
# 3    66
# Name: s, dtype: int32

# %%
f['g'] = f['b']-f['a']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_28612\21747924.py in <module>
# ----> 1 f['g'] = f['b']-f['a']
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3503             if self.columns.nlevels > 1:
#    3504                 return self._getitem_multilevel(key)
# -> 3505             indexer = self.columns.get_loc(key)
#    3506             if is_integer(indexer):
#    3507                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\range.py in get_loc(self, key, method, tolerance)
#     387                     raise KeyError(key) from err
#     388             self._check_indexing_error(key)
# --> 389             raise KeyError(key)
#     390         return super().get_loc(key, method=method, tolerance=tolerance)
#     391
#
# KeyError: 'b'

# %%
f.iloc[3:,2:]
# Out:
#     2   3
# s  46  66
# t  18  92
# u  59  59

# %%
f.iloc[-3:,-3:]
# Out:
#     1   2   3
# s  36  46  66
# t  63  18  92
# u  90  59  59

# %%
f['g'] = f[2]-f[1]

# %%
f
# Out:
#     0   1   2   3
# p  97  94  83  76
# q  98  34  68  41
# r  44  59  32  45
# s  54  36  46  66
# t  87  63  18  92
# u  40  90  59  59

# %%
f.iloc[2:4,1:3]
# Out:
#     1   2
# r  59  32
# s  36  46

# %%
f>10  # Masking
# Out:
#       0     1     2     3
# p  True  True  True  True
# q  True  True  True  True
# r  True  True  True  True
# s  True  True  True  True
# t  True  True  True  True
# u  True  True  True  True

# %%
f[f<1]
# Out:
#     0   1   2   3
# p NaN NaN NaN NaN
# q NaN NaN NaN NaN
# r NaN NaN NaN NaN
# s NaN NaN NaN NaN
# t NaN NaN NaN NaN
# u NaN NaN NaN NaN

# %%
(f==10) & (f==20)

# %%
pd.read_csv('https://gist.githubusercontent.com/curran/a08a1080b88344b0c8a7/raw/0e7a9b0a5d22642a06d3d5b9bcbad9890c8ee534/iris.csv')
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
f = pd.read_csv('iris data.csv')

# %%
f
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
pd.read_html
# Out:
# <function pandas.io.html.read_html(io: 'FilePath | ReadBuffer[str]', match: 'str | Pattern' = '.+', flavor: 'str | None' = None, header: 'int | Sequence[int] | None' = None, index_col: 'int | Sequence[int] | None' = None, skiprows: 'int | Sequence[int] | slice | None' = None, attrs: 'dict[str, str] | None' = None, parse_dates: 'bool' = False, thousands: 'str | None' = ',', encoding: 'str | None' = None, decimal: 'str' = '.', converters: 'dict | None' = None, na_values=None, keep_default_na: 'bool' = True, displayed_only: 'bool' = True) -> 'list[DataFrame]'>

# %%
pd.read_json
# Out:
# <function pandas.io.json._json.read_json(path_or_buf=None, orient=None, typ='frame', dtype: 'DtypeArg | None' = None, convert_axes=None, convert_dates=True, keep_default_dates: 'bool' = True, numpy: 'bool' = False, precise_float: 'bool' = False, date_unit=None, encoding=None, encoding_errors: 'str | None' = 'strict', lines: 'bool' = False, chunksize: 'int | None' = None, compression: 'CompressionOptions' = 'infer', nrows: 'int | None' = None, storage_options: 'StorageOptions' = None)>

# %%
f.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
f.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
f.sample()
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species
# 20           5.4          3.4           1.7          0.2  setosa

# %%
f.sample(3)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 81            5.5          2.4           3.7          1.0  versicolor
# 89            5.5          2.5           4.0          1.3  versicolor
# 115           6.4          3.2           5.3          2.3   virginica

# %%
f.shape
# Out:
# (150, 5)

# %%
f.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
f.index
# Out:
# RangeIndex(start=0, stop=150, step=1)

# %%
f.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
f.info
# Out:
# <bound method DataFrame.info of      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]>

# %%
f.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
f.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
f.describe(include='all')
# Out:
#         sepal_length  sepal_width  petal_length  petal_width species
# count     150.000000   150.000000    150.000000   150.000000     150
# unique           NaN          NaN           NaN          NaN       3
# top              NaN          NaN           NaN          NaN  setosa
# freq             NaN          NaN           NaN          NaN      50
# mean        5.843333     3.054000      3.758667     1.198667     NaN
# std         0.828066     0.433594      1.764420     0.763161     NaN
# min         4.300000     2.000000      1.000000     0.100000     NaN
# 25%         5.100000     2.800000      1.600000     0.300000     NaN
# 50%         5.800000     3.000000      4.350000     1.300000     NaN
# 75%         6.400000     3.300000      5.100000     1.800000     NaN
# max         7.900000     4.400000      6.900000     2.500000     NaN

# %%
# !pip install pandas

# %%
import numpy as np

# %%
import pandas as pd

# %%
j = np.random.randint(10,100,size = (6,4))
j
# Out:
# array([[39, 65, 99, 92],
#        [92, 77, 47, 29],
#        [37, 64, 67, 27],
#        [21, 18, 46, 89],
#        [52, 67, 86, 91],
#        [79, 45, 76, 20]])

# %%
f = pd.DataFrame(j)

# %%
f
# Out:
#     0   1   2   3
# 0  39  65  99  92
# 1  92  77  47  29
# 2  37  64  67  27
# 3  21  18  46  89
# 4  52  67  86  91
# 5  79  45  76  20

# %%
f = pd.read_csv('iris data.csv')

# %%
f
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
f['species']
# Out:
# 0         setosa
# 1         setosa
# 2         setosa
# 3         setosa
# 4         setosa
#          ...
# 145    virginica
# 146    virginica
# 147    virginica
# 148    virginica
# 149    virginica
# Name: species, Length: 150, dtype: object

# %%
f['species'].nunique()
# Out:
# 3

# %%
f.species.unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
f[f['species'] == 'versicolor']
# Out:
#     sepal_length  sepal_width  petal_length  petal_width     species
# 50           7.0          3.2           4.7          1.4  versicolor
# 51           6.4          3.2           4.5          1.5  versicolor
# 52           6.9          3.1           4.9          1.5  versicolor
# 53           5.5          2.3           4.0          1.3  versicolor
# 54           6.5          2.8           4.6          1.5  versicolor
# 55           5.7          2.8           4.5          1.3  versicolor
# 56           6.3          3.3           4.7          1.6  versicolor
# 57           4.9          2.4           3.3          1.0  versicolor
# 58           6.6          2.9           4.6          1.3  versicolor
# 59           5.2          2.7           3.9          1.4  versicolor
# 60           5.0          2.0           3.5          1.0  versicolor
# 61           5.9          3.0           4.2          1.5  versicolor
# 62           6.0          2.2           4.0          1.0  versicolor
# ...

# %%
versicolor = f[f['species'] == 'versicolor']

# %%
versicolor.shape
# Out:
# (50, 5)

# %%
f.species.value_counts()['setosa']
# Out:
# 50

# %%
f.species.value_counts()
# Out:
# setosa        50
# versicolor    50
# virginica     50
# Name: species, dtype: int64

# %%
f['petal_length']
# Out:
# 0      1.4
# 1      1.4
# 2      1.3
# 3      1.5
# 4      1.4
#       ...
# 145    5.2
# 146    5.0
# 147    5.2
# 148    5.4
# 149    5.1
# Name: petal_length, Length: 150, dtype: float64

# %%
f.petal_length.max()
# Out:
# 6.9

# %%
f.petal_length.min()
# Out:
# 1.0

# %%
f.petal_length.mean()
# Out:
# 3.7586666666666693

# %%
f.petal_length.median()
# Out:
# 4.35

# %%
f.petal_length.sum()
# Out:
# 563.8

# %%
f["petal_length"].min()
# Out:
# 1.0

# %%
f.sort_index()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
f.sort_values(by='sepal_length')
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 13            4.3          3.0           1.1          0.1     setosa
# 42            4.4          3.2           1.3          0.2     setosa
# 38            4.4          3.0           1.3          0.2     setosa
# 8             4.4          2.9           1.4          0.2     setosa
# 41            4.5          2.3           1.3          0.3     setosa
# ..            ...          ...           ...          ...        ...
# 122           7.7          2.8           6.7          2.0  virginica
# 118           7.7          2.6           6.9          2.3  virginica
# 117           7.7          3.8           6.7          2.2  virginica
# 135           7.7          3.0           6.1          2.3  virginica
# 131           7.9          3.8           6.4          2.0  virginica
#
# [150 rows x 5 columns]

# %%
f.sort_values(by='sepal_length',ascending=False)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 131           7.9          3.8           6.4          2.0  virginica
# 135           7.7          3.0           6.1          2.3  virginica
# 122           7.7          2.8           6.7          2.0  virginica
# 117           7.7          3.8           6.7          2.2  virginica
# 118           7.7          2.6           6.9          2.3  virginica
# ..            ...          ...           ...          ...        ...
# 41            4.5          2.3           1.3          0.3     setosa
# 42            4.4          3.2           1.3          0.2     setosa
# 38            4.4          3.0           1.3          0.2     setosa
# 8             4.4          2.9           1.4          0.2     setosa
# 13            4.3          3.0           1.1          0.1     setosa
#
# [150 rows x 5 columns]

# %%
f.sort_values(by='sepal_length',ascending=False, inplace=True)

# %%
f
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 131           7.9          3.8           6.4          2.0  virginica
# 117           7.7          3.8           6.7          2.2  virginica
# 118           7.7          2.6           6.9          2.3  virginica
# 135           7.7          3.0           6.1          2.3  virginica
# 122           7.7          2.8           6.7          2.0  virginica
# ..            ...          ...           ...          ...        ...
# 41            4.5          2.3           1.3          0.3     setosa
# 42            4.4          3.2           1.3          0.2     setosa
# 38            4.4          3.0           1.3          0.2     setosa
# 8             4.4          2.9           1.4          0.2     setosa
# 13            4.3          3.0           1.1          0.1     setosa
#
# [150 rows x 5 columns]

# %%
f.sort_values(by=['sepal_length','sepal_width'],ascending=False)

# %%
f.sort_values(by='sepal_width')
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 60            5.0          2.0           3.5          1.0  versicolor
# 119           6.0          2.2           5.0          1.5   virginica
# 68            6.2          2.2           4.5          1.5  versicolor
# 62            6.0          2.2           4.0          1.0  versicolor
# 53            5.5          2.3           4.0          1.3  versicolor
# ..            ...          ...           ...          ...         ...
# 5             5.4          3.9           1.7          0.4      setosa
# 14            5.8          4.0           1.2          0.2      setosa
# 32            5.2          4.1           1.5          0.1      setosa
# 33            5.5          4.2           1.4          0.2      setosa
# 15            5.7          4.4           1.5          0.4      setosa
#
# [150 rows x 5 columns]

# %%
f.sort_values(by=['sepal_width',"sepal_length"])

# %%
f
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 131           7.9          3.8           6.4          2.0  virginica
# 117           7.7          3.8           6.7          2.2  virginica
# 118           7.7          2.6           6.9          2.3  virginica
# 135           7.7          3.0           6.1          2.3  virginica
# 122           7.7          2.8           6.7          2.0  virginica
# ..            ...          ...           ...          ...        ...
# 41            4.5          2.3           1.3          0.3     setosa
# 42            4.4          3.2           1.3          0.2     setosa
# 38            4.4          3.0           1.3          0.2     setosa
# 8             4.4          2.9           1.4          0.2     setosa
# 13            4.3          3.0           1.1          0.1     setosa
#
# [150 rows x 5 columns]

# %%
f.species.apply(len) #len function is used to count the length

# %%
f.apply(lambda x:x+x)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width             species
# 131          15.8          7.6          12.8          4.0  virginicavirginica
# 117          15.4          7.6          13.4          4.4  virginicavirginica
# 118          15.4          5.2          13.8          4.6  virginicavirginica
# 135          15.4          6.0          12.2          4.6  virginicavirginica
# 122          15.4          5.6          13.4          4.0  virginicavirginica
# ..            ...          ...           ...          ...                 ...
# 41            9.0          4.6           2.6          0.6        setosasetosa
# 42            8.8          6.4           2.6          0.4        setosasetosa
# 38            8.8          6.0           2.6          0.4        setosasetosa
# 8             8.8          5.8           2.8          0.4        setosasetosa
# 13            8.6          6.0           2.2          0.2        setosasetosa
#
# [150 rows x 5 columns]

# %%
f.apply(len)

# %%
f
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 131           7.9          3.8           6.4          2.0  virginica
# 117           7.7          3.8           6.7          2.2  virginica
# 118           7.7          2.6           6.9          2.3  virginica
# 135           7.7          3.0           6.1          2.3  virginica
# 122           7.7          2.8           6.7          2.0  virginica
# ..            ...          ...           ...          ...        ...
# 41            4.5          2.3           1.3          0.3     setosa
# 42            4.4          3.2           1.3          0.2     setosa
# 38            4.4          3.0           1.3          0.2     setosa
# 8             4.4          2.9           1.4          0.2     setosa
# 13            4.3          3.0           1.1          0.1     setosa
#
# [150 rows x 5 columns]

# %%
f
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 131           7.9          3.8           6.4          2.0  virginica
# 117           7.7          3.8           6.7          2.2  virginica
# 118           7.7          2.6           6.9          2.3  virginica
# 135           7.7          3.0           6.1          2.3  virginica
# 122           7.7          2.8           6.7          2.0  virginica
# ..            ...          ...           ...          ...        ...
# 41            4.5          2.3           1.3          0.3     setosa
# 42            4.4          3.2           1.3          0.2     setosa
# 38            4.4          3.0           1.3          0.2     setosa
# 8             4.4          2.9           1.4          0.2     setosa
# 13            4.3          3.0           1.1          0.1     setosa
#
# [150 rows x 5 columns]

# %%
f.species.sepal_length()['setosa']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_28612\1892607817.py in <module>
# ----> 1 f.species.sepal_length()['setosa']
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'sepal_length'

# %%
f.species.setosa
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_28612\4192916780.py in <module>
# ----> 1 f.species.setosa
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'setosa'

# %%
f.sort_values(by='sepal_length')
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 13            4.3          3.0           1.1          0.1     setosa
# 42            4.4          3.2           1.3          0.2     setosa
# 8             4.4          2.9           1.4          0.2     setosa
# 38            4.4          3.0           1.3          0.2     setosa
# 41            4.5          2.3           1.3          0.3     setosa
# ..            ...          ...           ...          ...        ...
# 122           7.7          2.8           6.7          2.0  virginica
# 135           7.7          3.0           6.1          2.3  virginica
# 118           7.7          2.6           6.9          2.3  virginica
# 117           7.7          3.8           6.7          2.2  virginica
# 131           7.9          3.8           6.4          2.0  virginica
#
# [150 rows x 5 columns]

# %%
f.species.
# Out:
#   File "C:\Users\harsh\AppData\Local\Temp\ipykernel_28612\2843839463.py", line 1
#     f.species.
#               ^
# SyntaxError: invalid syntax

# %%
f[f['species'] == 'setosa']
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species
# 14           5.8          4.0           1.2          0.2  setosa
# 18           5.7          3.8           1.7          0.3  setosa
# 15           5.7          4.4           1.5          0.4  setosa
# 36           5.5          3.5           1.3          0.2  setosa
# 33           5.5          4.2           1.4          0.2  setosa
# 20           5.4          3.4           1.7          0.2  setosa
# 31           5.4          3.4           1.5          0.4  setosa
# 5            5.4          3.9           1.7          0.4  setosa
# 10           5.4          3.7           1.5          0.2  setosa
# 16           5.4          3.9           1.3          0.4  setosa
# 48           5.3          3.7           1.5          0.2  setosa
# 27           5.2          3.5           1.5          0.2  setosa
# 28           5.2          3.4           1.4          0.2  setosa
# ...

# %%
g =   [f.petal_length.f[f['species'] == 'setosa']] min()
# Out:
#   File "C:\Users\harsh\AppData\Local\Temp\ipykernel_28612\4209865981.py", line 1
#     g =   [f.petal_length.f[f['species'] == 'setosa']] min()
#                                                        ^
# SyntaxError: invalid syntax

# %%
f
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 131           7.9          3.8           6.4          2.0  virginica
# 117           7.7          3.8           6.7          2.2  virginica
# 118           7.7          2.6           6.9          2.3  virginica
# 135           7.7          3.0           6.1          2.3  virginica
# 122           7.7          2.8           6.7          2.0  virginica
# ..            ...          ...           ...          ...        ...
# 41            4.5          2.3           1.3          0.3     setosa
# 42            4.4          3.2           1.3          0.2     setosa
# 38            4.4          3.0           1.3          0.2     setosa
# 8             4.4          2.9           1.4          0.2     setosa
# 13            4.3          3.0           1.1          0.1     setosa
#
# [150 rows x 5 columns]

# %%
ls
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is 46C8-E9DC
#
#  Directory of C:\Users\harsh\Desktop\DATA SCIENCE
#
# 22-06-2023  17:15    <DIR>          .
# 20-06-2023  14:41    <DIR>          ..
# 22-06-2023  17:09    <DIR>          .ipynb_checkpoints
# 07-06-2023  16:33        54,688,392 1.mp4
# 12-06-2023  10:54        53,391,499 2.mp4
# 12-06-2023  10:54        52,251,833 3.mp4
# 13-06-2023  11:20        53,993,635 4.mp4
# 14-06-2023  11:48        28,765,294 5.mp4
# 15-06-2023  12:32        58,876,370 6.mp4
# 20-06-2023  14:22       151,053,630 7.mp4
# 22-06-2023  12:51        72,735,803 8.mp4
# 22-06-2023  12:21        78,799,658 9.mp4
# 20-06-2023  17:34             3,858 iris data.csv
# 18-06-2023  23:30           114,679 numpy.ipynb
# 18-06-2023  23:16               148 outfile.npy
# 22-06-2023  17:09           106,419 PAMNDAS PRACTICE.ipynb
# 22-06-2023  17:08           106,419 pandas practice.ipynb
# 22-06-2023  17:15           201,008 PANDAS_.ipynb
# ...

# %%
pd.read_csv(r'C:\Users\harsh\Desktop\DATA SCIENCE\iris data.csv')  # absolute method by using r in front and copying the location from properties
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
f
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 131           7.9          3.8           6.4          2.0  virginica
# 117           7.7          3.8           6.7          2.2  virginica
# 118           7.7          2.6           6.9          2.3  virginica
# 135           7.7          3.0           6.1          2.3  virginica
# 122           7.7          2.8           6.7          2.0  virginica
# ..            ...          ...           ...          ...        ...
# 41            4.5          2.3           1.3          0.3     setosa
# 42            4.4          3.2           1.3          0.2     setosa
# 38            4.4          3.0           1.3          0.2     setosa
# 8             4.4          2.9           1.4          0.2     setosa
# 13            4.3          3.0           1.1          0.1     setosa
#
# [150 rows x 5 columns]

# %%
pd.read_csv('C:/Users/harsh/Desktop/DATA SCIENCE/iris data.csv')  # second method of using absolute value is to replace the (\) front slash with back slash(/)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
pd.read_csv('C://Users//harsh//Desktop//DATA SCIENCE//iris data.csv') # third method is by using // double back slash
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
f[f['species'] == 'setosa']['sepal_length'].min()
# Out:
# 4.3

# %%
f[f['species'] == 'virginica']['petal_length'].max()
# Out:
# 6.9

# %%
f.aggregate('min')
# Out:
# sepal_length       4.3
# sepal_width        2.0
# petal_length       1.0
# petal_width        0.1
# species         setosa
# dtype: object

# %%
f.aggregate(['min','max','mean','median','std'])
# Out:
# C:\Users\harsh\AppData\Local\Temp\ipykernel_28612\3189198029.py:1: FutureWarning: ['species'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   f.aggregate(['min','max','mean','median','std'])
#         sepal_length  sepal_width  petal_length  petal_width    species
# min         4.300000     2.000000      1.000000     0.100000     setosa
# max         7.900000     4.400000      6.900000     2.500000  virginica
# mean        5.843333     3.054000      3.758667     1.198667        NaN
# median      5.800000     3.000000      4.350000     1.300000        NaN
# std         0.828066     0.433594      1.764420     0.763161        NaN

# %%
obj = f.groupby('species')

# %%
obj

# %%
obj.aggregate
# Out:
# <bound method DataFrameGroupBy.aggregate of <pandas.core.groupby.generic.DataFrameGroupBy object at 0x00000270E67AE7C0>>

# %%
obj.all
# Out:
# <bound method GroupBy.all of <pandas.core.groupby.generic.DataFrameGroupBy object at 0x00000270E67AE7C0>>

# %%
obj.min()
# Out:
#             sepal_length  sepal_width  petal_length  petal_width
# species
# setosa               4.3          2.3           1.0          0.1
# versicolor           4.9          2.0           3.0          1.0
# virginica            4.9          2.2           4.5          1.4

# %%
obj.max()
# Out:
#             sepal_length  sepal_width  petal_length  petal_width
# species
# setosa               5.8          4.4           1.9          0.6
# versicolor           7.0          3.4           5.1          1.8
# virginica            7.9          3.8           6.9          2.5

# %%
obj.count()
# Out:
#             sepal_length  sepal_width  petal_length  petal_width
# species
# setosa                50           50            50           50
# versicolor            50           50            50           50
# virginica             50           50            50           50

# %%
obj.describe().T  # Transpose
# Out:
# species                setosa  versicolor  virginica
# sepal_length count  50.000000   50.000000  50.000000
#              mean    5.006000    5.936000   6.588000
#              std     0.352490    0.516171   0.635880
#              min     4.300000    4.900000   4.900000
#              25%     4.800000    5.600000   6.225000
#              50%     5.000000    5.900000   6.500000
#              75%     5.200000    6.300000   6.900000
#              max     5.800000    7.000000   7.900000
# sepal_width  count  50.000000   50.000000  50.000000
#              mean    3.418000    2.770000   2.974000
#              std     0.381024    0.313798   0.322497
#              min     2.300000    2.000000   2.200000
#              25%     3.125000    2.525000   2.800000
#              50%     3.400000    2.800000   3.000000
#              75%     3.675000    3.000000   3.175000
#              max     4.400000    3.400000   3.800000
# petal_length count  50.000000   50.000000  50.000000
# ...

# %%
f.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
import numpy as np

# %%
nan_id = np.random.randint(0,150,20)

# %%
nan_id
# Out:
# array([ 25,   0, 111,  24,  86,  48,  74,  76,   1, 126,  60,  21,  59,
#        138,  43,  62, 124,  78,  17, 108])

# %%
f['sepal_length'][nan_id] = np.nan
# Out:
# C:\Users\harsh\AppData\Local\Temp\ipykernel_28612\2830848241.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f['sepal_length'][nan_id] = np.nan

# %%
f['sepal_length'][:50]
# Out:
# 131    7.9
# 117    7.7
# 118    7.7
# 135    7.7
# 122    7.7
# 105    7.6
# 130    7.4
# 107    7.3
# 125    7.2
# 129    7.2
# 109    7.2
# 102    7.1
# 50     7.0
# 120    6.9
# 52     6.9
# 139    6.9
# 141    6.9
# 76     NaN
# 112    6.8
# 143    6.8
# 108    NaN
# 86     NaN
# 124    NaN
# 145    6.7
# 65     6.7
# 144    6.7
# 140    6.7
# 77     6.7
# 75     6.6
# 58     6.6
# 116    6.5
# 54     6.5
# 110    6.5
# 104    6.5
# 147    6.5
# 51     6.4
# 74     NaN
# 128    6.4
# 137    6.4
# 111    NaN
# 132    6.4
# 115    6.4
# 100    6.3
# 136    6.3
# 72     6.3
# 56     6.3
# 103    6.3
# 133    6.3
# 87     6.3
# 146    6.3
# Name: sepal_length, dtype: float64

# %%
f.isna().sum()
# Out:
# sepal_length    32
# sepal_width      0
# petal_length     0
# petal_width      0
# species         17
# dtype: int64

# %%
f.shape
# Out:
# (150, 5)

# %%
f.dropna()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 131           7.9          3.8           6.4          2.0  virginica
# 117           7.7          3.8           6.7          2.2  virginica
# 118           7.7          2.6           6.9          2.3  virginica
# 135           7.7          3.0           6.1          2.3  virginica
# 122           7.7          2.8           6.7          2.0  virginica
# ..            ...          ...           ...          ...        ...
# 6             4.6          3.4           1.4          0.3     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 38            4.4          3.0           1.3          0.2     setosa
# 8             4.4          2.9           1.4          0.2     setosa
# 13            4.3          3.0           1.1          0.1     setosa
#
# [118 rows x 5 columns]

# %%
k = f.dropna(inplace=True)

# %%
f['sepal_length'].fillna(value='king')
# Out:
# 131    7.9
# 117    7.7
# 118    7.7
# 135    7.7
# 122    7.7
#       ...
# 6      4.6
# 3      4.6
# 38     4.4
# 8      4.4
# 13     4.3
# Name: sepal_length, Length: 118, dtype: float64

# %%
round(f['sepal_length'].mean(),1) # 1 yaha per ye denote karra hai ki decimal ke baad kitni place lega
# Out:
# 5.9

# %%
f['sepal_length'].fillna(value=round(f['sepal_length'].mean(),1), inplace=True)

# %%
f
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 131           7.9          3.8           6.4          2.0  virginica
# 117           7.7          3.8           6.7          2.2  virginica
# 118           7.7          2.6           6.9          2.3  virginica
# 135           7.7          3.0           6.1          2.3  virginica
# 122           7.7          2.8           6.7          2.0  virginica
# ..            ...          ...           ...          ...        ...
# 6             4.6          3.4           1.4          0.3     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 38            4.4          3.0           1.3          0.2     setosa
# 8             4.4          2.9           1.4          0.2     setosa
# 13            4.3          3.0           1.1          0.1     setosa
#
# [118 rows x 5 columns]

# %%
f.isna().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
new = pd.DataFrame(np.random.randint(0,7,size=(10,4)))

# %%
new
# Out:
#    0  1  2  3
# 0  6  2  6  1
# 1  1  1  1  6
# 2  4  0  6  5
# 3  0  4  0  2
# 4  3  5  6  0
# 5  4  6  2  4
# 6  0  3  1  4
# 7  2  1  1  6
# 8  6  1  1  5
# 9  3  1  0  5

# %%
new['species'] = 'new_species'

# %%
new
# Out:
#    0  1  2  3      species
# 0  6  2  6  1  new_species
# 1  1  1  1  6  new_species
# 2  4  0  6  5  new_species
# 3  0  4  0  2  new_species
# 4  3  5  6  0  new_species
# 5  4  6  2  4  new_species
# 6  0  3  1  4  new_species
# 7  2  1  1  6  new_species
# 8  6  1  1  5  new_species
# 9  3  1  0  5  new_species

# %%
new.column=['sepal_length','sepal_width','petal_length','petal_width']
# Out:
# C:\Users\harsh\AppData\Local\Temp\ipykernel_28612\4215217593.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   new.column=['sepal_length','sepal_width','petal_length','petal_width']

# %%
new
# Out:
#    0  1  2  3      species
# 0  6  2  6  1  new_species
# 1  1  1  1  6  new_species
# 2  4  0  6  5  new_species
# 3  0  4  0  2  new_species
# 4  3  5  6  0  new_species
# 5  4  6  2  4  new_species
# 6  0  3  1  4  new_species
# 7  2  1  1  6  new_species
# 8  6  1  1  5  new_species
# 9  3  1  0  5  new_species
